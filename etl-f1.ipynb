# %% [markdown]
# Vamos a trabajar con la pagina https://ergast.com/mrd/

# %% [markdown]
# Note que la forma es la siguiente:
# http[s]://ergast.com/api/ series/season/round/
#  Donde:
#
# series.	should be set to "f1"
# season:	is a 4 digit integer
# round:	is a 1 or 2 digit integer

# %% [markdown]
# ## Librerias

# %%
import  requests
import pandas as pd

# %%
url='https://ergast.com/api/f1/2022/22/results.json'

# %%
r=requests.get(url)
json=r.json()

# %% [markdown]
# Veremos que claves contiene nuestro json

# %%
json.keys()
# Out:
# dict_keys(['MRData'])

# %%
json['MRData'].keys()
# Out:
# dict_keys(['xmlns', 'series', 'url', 'limit', 'offset', 'total', 'RaceTable'])

# %% [markdown]
# Podemos observar que solo tiene una clave. Ahora nosotrps queremos ver las carreras.

# %%
json['MRData']['RaceTable']['Races'][0]
# Out:
# {'season': '2022',
#  'round': '22',
#  'url': 'http://en.wikipedia.org/wiki/2022_Abu_Dhabi_Grand_Prix',
#  'raceName': 'Abu Dhabi Grand Prix',
#  'Circuit': {'circuitId': 'yas_marina',
#   'url': 'http://en.wikipedia.org/wiki/Yas_Marina_Circuit',
#   'circuitName': 'Yas Marina Circuit',
#   'Location': {'lat': '24.4672',
#    'long': '54.6031',
#    'locality': 'Abu Dhabi',
#    'country': 'UAE'}},
#  'date': '2022-11-20',
#  'time': '13:00:00Z',
#  'Results': [{'number': '1',
#    'position': '1',
#    'positionText': '1',
#    'points': '25',
#    'Driver': {'driverId': 'max_verstappen',
#     'permanentNumber': '33',
#     'code': 'VER',
#     'url': 'http://en.wikipedia.org/wiki/Max_Verstappen',
#     'givenName': 'Max',
#     'familyName': 'Verstappen',
#     'dateOfBirth': '1997-09-30',
#     'nationality': 'Dutch'},
#    'Constructor': {'constructorId': 'red_bull',
#     'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#     'name': 'Red Bull',
# ...

# %% [markdown]
# Esto ya es un diccionario

# %%
json['MRData']['RaceTable']['Races'][0].keys()
# Out:
# dict_keys(['season', 'round', 'url', 'raceName', 'Circuit', 'date', 'time', 'Results'])

# %%
Ahora trabajaremos con los resultados de las carreras

# %%
results=pd.DataFrame(json['MRData']['RaceTable']['Races'][0]['Results'])

# %%
results.head()
# Out:
#   number position positionText points  \
# 0      1        1            1     25
# 1     16        2            2     18
# 2     11        3            3     15
# 3     55        4            4     12
# 4     63        5            5     10
#
#                                               Driver  \
# 0  {'driverId': 'max_verstappen', 'permanentNumbe...
# 1  {'driverId': 'leclerc', 'permanentNumber': '16...
# 2  {'driverId': 'perez', 'permanentNumber': '11',...
# 3  {'driverId': 'sainz', 'permanentNumber': '55',...
# 4  {'driverId': 'russell', 'permanentNumber': '63...
#
#                                          Constructor grid laps    status  \
# 0  {'constructorId': 'red_bull', 'url': 'http://e...    1   58  Finished
# 1  {'constructorId': 'ferrari', 'url': 'http://en...    3   58  Finished
# 2  {'constructorId': 'red_bull', 'url': 'http://e...    2   58  Finished
# 3  {'constructorId': 'ferrari', 'url': 'http://en...    4   58  Finished
# ...

# %%
results['Driver']
# Out:
# 0     {'driverId': 'max_verstappen', 'permanentNumbe...
# 1     {'driverId': 'leclerc', 'permanentNumber': '16...
# 2     {'driverId': 'perez', 'permanentNumber': '11',...
# 3     {'driverId': 'sainz', 'permanentNumber': '55',...
# 4     {'driverId': 'russell', 'permanentNumber': '63...
# 5     {'driverId': 'norris', 'permanentNumber': '4',...
# 6     {'driverId': 'ocon', 'permanentNumber': '31', ...
# 7     {'driverId': 'stroll', 'permanentNumber': '18'...
# 8     {'driverId': 'ricciardo', 'permanentNumber': '...
# 9     {'driverId': 'vettel', 'permanentNumber': '5',...
# 10    {'driverId': 'tsunoda', 'permanentNumber': '22...
# 11    {'driverId': 'zhou', 'permanentNumber': '24', ...
# 12    {'driverId': 'albon', 'permanentNumber': '23',...
# 13    {'driverId': 'gasly', 'permanentNumber': '10',...
# 14    {'driverId': 'bottas', 'permanentNumber': '77'...
# 15    {'driverId': 'mick_schumacher', 'permanentNumb...
# 16    {'driverId': 'kevin_magnussen', 'permanentNumb...
# ...

# %% [markdown]
# A cada una de las entradas de drive, le vamos a aplicar la funcion ... para extraer  cada elemento de la columna driver

# %%
results['Driver']=results['Driver'].apply(lambda x:x['driverId'])

# %%
results.head()
# Out:
#   number position positionText points          Driver Constructor grid laps  \
# 0      1        1            1     25  max_verstappen    red_bull    1   58
# 1     16        2            2     18         leclerc     ferrari    3   58
# 2     11        3            3     15           perez    red_bull    2   58
# 3     55        4            4     12           sainz     ferrari    4   58
# 4     63        5            5     10         russell    mercedes    6   58
#
#      status                                          Time  \
# 0  Finished  {'millis': '5265914', 'time': '1:27:45.914'}
# 1  Finished       {'millis': '5274685', 'time': '+8.771'}
# 2  Finished      {'millis': '5276007', 'time': '+10.093'}
# 3  Finished      {'millis': '5290806', 'time': '+24.892'}
# 4  Finished      {'millis': '5301802', 'time': '+35.888'}
#
#                                           FastestLap
# 0  {'rank': '6', 'lap': '54', 'Time': {'time': '1...
# ...

# %%
results['Constructor']
# Out:
# 0         red_bull
# 1          ferrari
# 2         red_bull
# 3          ferrari
# 4         mercedes
# 5          mclaren
# 6           alpine
# 7     aston_martin
# 8          mclaren
# 9     aston_martin
# 10      alphatauri
# 11            alfa
# 12        williams
# 13      alphatauri
# 14            alfa
# 15            haas
# 16            haas
# 17        mercedes
# 18        williams
# 19          alpine
# Name: Constructor, dtype: object

# %%
results['Constructor']=results['Constructor'].apply(lambda x:x['constructorId'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13300\401152842.py in <module>
# ----> 1 results['Constructor']=results['Constructor'].apply(lambda x:x['constructorId'])
#
# NameError: name 'results' is not defined

# %%
results['Time'][0]['millis']
# Out:
# '5265914'

# %%
results['FastestLap']
# Out:
# 0      6
# 1     10
# 2      4
# 3      3
# 4      2
# 5      1
# 6      5
# 7      9
# 8     18
# 9     15
# 10     7
# 11     8
# 12    13
# 13    19
# 14    16
# 15    12
# 16    20
# 17    11
# 18    14
# 19    17
# Name: FastestLap, dtype: object

# %%
results['FastestLap']=results['FastestLap'].apply(lambda x:x['rank'])
